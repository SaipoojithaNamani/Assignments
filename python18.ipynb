# %% [markdown]
# <a href="https://colab.research.google.com/github/SaipoojithaNamani/Assignments/blob/main/python18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as pyplot
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
cars = pd.read_csv(r"/content/Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.head(4)
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114

# %%
cars.tail(14)
# Out:
#      HP        MPG  VOL          SP         WT
# 67  165  23.103172  127  133.680223  41.573975
# 68  165  23.103172  123  133.312342  40.472042
# 69  245  21.273708  112  158.300669  37.141733
# 70  280  19.678507   50  164.598513  15.823060
# 71  162  23.203569  135  133.415985  44.013139
# 72  162  23.203569  132  133.140074  43.353123
# 73  140  19.086341  160  124.715241  52.997752
# 74  140  19.086341  129  121.864163  42.618698
# 75  175  18.762837  129  132.864163  42.778219
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615

# %%
cars.isnull()
# Out:
#        HP    MPG    VOL     SP     WT
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False  False  False  False  False
# 3   False  False  False  False  False
# 4   False  False  False  False  False
# ..    ...    ...    ...    ...    ...
# 76  False  False  False  False  False
# 77  False  False  False  False  False
# 78  False  False  False  False  False
# 79  False  False  False  False  False
# 80  False  False  False  False  False
#
# [81 rows x 5 columns]

# %%
cars.isnull().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars.shape
# Out:
# (81, 5)

# %%
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
sns.displot(cars['HP'])

# %%
sns.displot(cars['MPG'])

# %%
sns.displot(cars['VOL'])

# %%
sns.displot(cars['SP'])

# %%
sns.displot(cars['WT'])

# %%
sns.boxplot(x=cars['HP'],palette=['violet','red','lightgreen'],y=cars['HP'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-83d44fafda9e> in <cell line: 0>()
#       1 sns.boxplot(x=cars['HP'],palette=['violet','red','lightgreen'],y=cars['HP'])
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.boxplot(cars['WT'])

# %%
sns.scatterplot(cars['MPG'])

# %%
sns.scatterplot(cars['HP'])

# %%
cars

# %%
sns.scatterplot(cars['VOL'])
# Out:
# <Axes: ylabel='VOL'>

# %%
sns.scatterplot(cars['SP'])
# Out:
# <Axes: ylabel='SP'>

# %%
sns.scatterplot(x = cars['SP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='SP', ylabel='MPG'>

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.heatmap(cars.corr(), cmap = 'Blues', annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-d18feb407054> in <cell line: 0>()
#       1 sns.heatmap(cars.corr(), cmap = 'Blues', annot=True)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
cars.corr()

# %%
sns.heatmap(cars.corr(),cmap='Blues',annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x = cars['SP'],y=cars['HP'])
# Out:
# <Axes: xlabel='SP', ylabel='HP'>

# %%
sns.scatterplot(x = cars['HP'],y=cars['VOL'])
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
sns.scatterplot(x = cars['SP'],y=cars['WT'])
# Out:
# <Axes: xlabel='SP', ylabel='WT'>

# %%
sns.scatterplot(x = cars['VOL'],y=cars['SP'])
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>

# %%
sns.scatterplot(x = cars['VOL'],y=cars['WT'])
# Out:
# <Axes: xlabel='VOL', ylabel='WT'>

# %%
sns.scatterplot(x = cars['SP'],y=cars['WT'])
# Out:
# <Axes: xlabel='SP', ylabel='WT'>

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
cars[['HP','WT','VOL','SP']]=sc.fit_transform(cars[['HP','WT','VOL','SP']])

# %%
ml_w=smf.ols('WT~SP',data=cars).fit()
ml_w.rsquared
# Out:
# 0.01049378784879651

# %%
model=smf.ols('MPG~WT+VOL+SP+HP', data=cars).fit()

# %%
model.params
# Out:
# Intercept    34.422076
# WT            2.982842
# VOL          -7.448031
# SP            5.575816
# HP          -11.660955
# dtype: float64

# %%
model.rsquared
# Out:
# 0.7705372737359844

# %%
MPG= 0.359*WT -0.888*VOL + 0.666*SP -1.348*HP + 0.898
