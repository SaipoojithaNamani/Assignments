# %% [markdown]
# <a href="https://colab.research.google.com/github/SaipoojithaNamani/Assignments/blob/main/decision_tree_streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install the module
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 30.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 45.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns
from  sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score,recall_score,f1_score,roc_auc_score,confusion_matrix

# %%
data=pd.read_csv("/content/Heart_Disease_Dataset.csv")

# %%
data
# Out:
#       HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0              Yes  14.96     Yes             Yes     No               7
# 1              Yes  36.93     Yes             Yes     No               3
# 2               No  18.70     Yes              No    Yes              26
# 3              Yes  31.43     Yes             Yes    Yes              24
# 4              Yes  75.64      No              No    Yes               2
# ...            ...    ...     ...             ...    ...             ...
# 80208           No  60.19      No              No    Yes              15
# 80209          Yes  58.30      No             Yes    Yes              12
# 80210          Yes  75.46     Yes             Yes    Yes               3
# 80211           No  18.70      No             Yes     No              20
# 80212          Yes  59.29     Yes             Yes    Yes              23
#
#        MentalHealth DiffWalking     Sex AgeCategory  \
# ...

# %%
data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0          Yes  14.96     Yes             Yes     No               7
# 1          Yes  36.93     Yes             Yes     No               3
# 2           No  18.70     Yes              No    Yes              26
# 3          Yes  31.43     Yes             Yes    Yes              24
# 4          Yes  75.64      No              No    Yes               2
#
#    MentalHealth DiffWalking     Sex AgeCategory  \
# 0             6         Yes  Female       25-29
# 1            10          No  Female       30-34
# 2            15          No    Male       70-74
# 3            20          No  Female       40-44
# 4            29          No    Male       35-39
#
#                              Race                 Diabetic PhysicalActivity  \
# 0                           White                      Yes              Yes
# 1                        Hispanic  No, borderline diabetes              Yes
# ...

# %%
data.tail(10)
# Out:
#       HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 80203           No  69.86     Yes              No    Yes               0
# 80204          Yes  65.23     Yes             Yes    Yes              29
# 80205           No  87.12     Yes             Yes     No               7
# 80206           No  73.76      No             Yes    Yes               4
# 80207          Yes  94.68     Yes              No     No              15
# 80208           No  60.19      No              No    Yes              15
# 80209          Yes  58.30      No             Yes    Yes              12
# 80210          Yes  75.46     Yes             Yes    Yes               3
# 80211           No  18.70      No             Yes     No              20
# 80212          Yes  59.29     Yes             Yes    Yes              23
#
#        MentalHealth DiffWalking     Sex  AgeCategory  \
# 80203            20          No  Female        70-74
# 80204             8         Yes  Female  80 or older
# ...

# %%
data.isnull()
# Out:
#        HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             False  False    False            False   False           False
# 1             False  False    False            False   False           False
# 2             False  False    False            False   False           False
# 3             False  False    False            False   False           False
# 4             False  False    False            False   False           False
# ...             ...    ...      ...              ...     ...             ...
# 80208         False  False    False            False   False           False
# 80209         False  False    False            False   False           False
# 80210         False  False    False            False   False           False
# 80211         False  False    False            False   False           False
# 80212         False  False    False            False   False           False
#
# ...

# %%
data.shape
# Out:
# (80213, 18)

# %%
data.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              1
# KidneyDisease       1
# SkinCancer          1
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80213 entries, 0 to 80212
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   HeartDisease      80213 non-null  object
#  1   BMI               80213 non-null  float64
#  2   Smoking           80213 non-null  object
#  3   AlcoholDrinking   80213 non-null  object
#  4   Stroke            80213 non-null  object
#  5   PhysicalHealth    80213 non-null  int64
#  6   MentalHealth      80213 non-null  int64
#  7   DiffWalking       80213 non-null  object
#  8   Sex               80213 non-null  object
#  9   AgeCategory       80213 non-null  object
#  10  Race              80213 non-null  object
#  11  Diabetic          80213 non-null  object
#  12  PhysicalActivity  80213 non-null  object
#  13  GenHealth         80213 non-null  object
#  14  SleepTime         80213 non-null  float64
#  15  Asthma            80212 non-null  object
# ...

# %%
## statistical analysis
data.describe()
# Out:
#                 BMI  PhysicalHealth  MentalHealth     SleepTime
# count  80213.000000    80213.000000  80213.000000  80213.000000
# mean      53.379124       14.512174     14.491055     12.482823
# std       23.885137        8.644212      8.653109      6.634137
# min       12.020000        0.000000      0.000000      1.000000
# 25%       32.770000        7.000000      7.000000      6.700000
# 50%       53.370000       14.000000     14.000000     12.500000
# 75%       74.010000       22.000000     22.000000     18.200000
# max       94.850000       29.000000     29.000000     24.000000

# %%
##duplicates checking
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 80208    False
# 80209    False
# 80210    False
# 80211    False
# 80212    False
# Length: 80213, dtype: bool

# %%
len(data[data.duplicated()])
# Out:
# 0

# %%
for column in data.columns:
  print(data[column].value_counts())
# Out:
# HeartDisease
# No     40207
# Yes    40006
# Name: count, dtype: int64
# BMI
# 50.49    24
# 43.94    22
# 21.75    21
# 56.38    21
# 40.92    21
#          ..
# 34.28     2
# 27.69     2
# 29.15     2
# 64.14     1
# 59.71     1
# Name: count, Length: 8284, dtype: int64
# Smoking
# Yes    40350
# No     39863
# Name: count, dtype: int64
# AlcoholDrinking
# Yes    40257
# No     39956
# Name: count, dtype: int64
# Stroke
# Yes    40305
# No     39908
# Name: count, dtype: int64
# PhysicalHealth
# 8     2773
# 29    2769
# 12    2754
# 16    2719
# 9     2718
# 19    2717
# 2     2714
# 14    2706
# 20    2705
# 13    2702
# 6     2688
# 28    2677
# 24    2673
# 15    2672
# 26    2671
# 23    2668
# 10    2667
# 7     2667
# 22    2662
# 1     2656
# 3     2655
# 11    2642
# 17    2637
# 18    2637
# 25    2636
# 0     2635
# 21    2610
# 27    2607
# 5     2595
# 4     2581
# Name: count, dtype: int64
# MentalHealth
# 22    2756
# 5     2756
# 16    2752
# 27    2739
# ...
